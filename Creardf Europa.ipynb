# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
from selenium.webdriver.chrome.options import Options
import sys
import regex as re
import pandas as pd

# %%
nombres = pd.read_csv('Data/name.csv')
Metros = pd.read_csv('Data/metros.csv')
pistas = pd.read_csv('Data/pistas.csv')
remontes = pd.read_csv('Data/remontes.csv')
precios = pd.read_csv('Data/precios.csv')
temporada = pd.read_csv('Data/Season.csv')

# %%
dfINAL = pd.concat([nombres,Metros,pistas,remontes,precios,temporada], axis=1)

# %%
dfINAL = dfINAL.drop('Unnamed: 0', 1)
# Out:
# <ipython-input-4-448f5175fe73>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dfINAL = dfINAL.drop('Unnamed: 0', 1)

# %%
dfINAL
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 0                    Lermoos – Grubigstein      __1004 m        2100 m
# 1    Latemar – Obereggen/Pampeago/Predazzo     __ 1540 m        2388 m
# 2                        Arosa Lenzerheide      __1229 m        2865 m
# 3         Ischgl/Samnaun – Silvretta Arena      __1360 m        2872 m
# 4         Ski Juwel Alpbachtal Wildschönau       __830 m        2025 m
# ..                                     ...           ...           ...
# 932                                 Pallas       __440 m         780 m
# 933                              Eikedalen       __457 m         918 m
# 934                      Valbella – Gallio      __1100 m        1311 m
# 935                Caldirola – Monte Gropà      __1075 m        1429 m
# 936   Kreuzberg – Bischofsheim an der Rhön       __610 m         928 m
#
#      Pistas_Totales   Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3   12.8          12.6        1.9               1.7    8.0
# 1              49.0    9.3          32.8        6.9               NaN   18.0
# 2             225.0  110.0          87.0       28.0               NaN   43.0
# 3             239.0   47.0         143.0       49.0              15.0   41.0
# 4              90.9   25.1          53.1       12.7              16.3   46.0
# ..              ...    ...           ...        ...               ...    ...
# 932            12.0    8.0           3.0        1.0               NaN    2.0
# 933            15.0   10.0           5.0        0.0               NaN    8.0
# 934            11.2    8.0           2.5        0.7               NaN    NaN
# 935             5.9    4.0           1.9        0.0               NaN    NaN
# 936            13.0    5.0           8.0        0.0               NaN    4.0
#
#              Adults           Youth  Children Current_season_start  \
# 0            49.50           39.50     25,-__           2021-12-04
# 1             52,-           37,-__       NaN           2021-11-26
# 2     78,- approx.    51,- approx.     25,-__           2021-10-30
# 3             55,-          34.50__       NaN           2021-11-25
# 4             51,-            41,-    25.50__           2021-12-03
# ..              ...             ...       ...                  ...
# 932             NaN             NaN       NaN                  NaN
# 933             NaN             NaN       NaN                  NaN
# 934             NaN             NaN       NaN                  NaN
# 935             NaN             NaN       NaN                  NaN
# 936           17,-           13,-__       NaN           2021-12-25
#
#     Current_season_finish General_season_start General_season_finish  \
# 0            2022-04-18__       early December           mid April__
# 1            2022-04-18__        late November          late April__
# 2            2022-04-18__       early November           mid April__
# 3            2022-05-01__        late November           early May__
# 4            2022-04-18__         mid December           mid April__
# ..                    ...                  ...                   ...
# 932                   NaN                  NaN                   NaN
# 933                   NaN                  NaN                   NaN
# 934                   NaN                  NaN                   NaN
# 935                   NaN                  NaN                   NaN
# 936          2022-03-13__         mid December           mid March__
#
#     Opening_time Closing_time
# 0          08:30      16:30__
# 1          08:30      16:30__
# 2          08:30      16:30__
# 3          08:30      16:00__
# 4          08:30      16:00__
# ..           ...          ...
# 932        09:00      16:00__
# 933        09:00      16:00__
# 934          NaN          NaN
# 935        08:30      17:00__
# 936        09:00      17:00__
#
# [937 rows x 18 columns]

# %%
def limpia_col(dfcol):
    for i in dfcol:
        a = dfcol.str.extract('((\d+)+(\.\d+)|(\d+))', flags=0)
        a = a.rename(columns={0:"Primera"})
    return a.Primera

# %%
dfINAL['Minima Altura'] = limpia_col(dfINAL['Minima Altura'])
dfINAL['Maxima Altura'] = limpia_col(dfINAL['Maxima Altura'])
dfINAL['Adults'] = limpia_col(dfINAL['Adults'])
dfINAL['Children'] = limpia_col(dfINAL['Children'])
dfINAL['Youth'] = limpia_col(dfINAL['Youth'])

# %%
lista1 = []
def quitar__(dfcol):
    for i in dfcol:
        try:
            a=i.replace("__", "")
            lista1.append(a)
        except:
            lista1.append('nan')
    a =  pd.DataFrame(lista1)
    dfcol = a[0]

# %%
quitar__(dfINAL.Current_season_finish)

# %%
dfINAL
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 0                    Lermoos – Grubigstein          1004          2100
# 1    Latemar – Obereggen/Pampeago/Predazzo          1540          2388
# 2                        Arosa Lenzerheide          1229          2865
# 3         Ischgl/Samnaun – Silvretta Arena          1360          2872
# 4         Ski Juwel Alpbachtal Wildschönau           830          2025
# ..                                     ...           ...           ...
# 932                                 Pallas           440           780
# 933                              Eikedalen           457           918
# 934                      Valbella – Gallio          1100          1311
# 935                Caldirola – Monte Gropà          1075          1429
# 936   Kreuzberg – Bischofsheim an der Rhön           610           928
#
#      Pistas_Totales   Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3   12.8          12.6        1.9               1.7    8.0
# 1              49.0    9.3          32.8        6.9               NaN   18.0
# 2             225.0  110.0          87.0       28.0               NaN   43.0
# 3             239.0   47.0         143.0       49.0              15.0   41.0
# 4              90.9   25.1          53.1       12.7              16.3   46.0
# ..              ...    ...           ...        ...               ...    ...
# 932            12.0    8.0           3.0        1.0               NaN    2.0
# 933            15.0   10.0           5.0        0.0               NaN    8.0
# 934            11.2    8.0           2.5        0.7               NaN    NaN
# 935             5.9    4.0           1.9        0.0               NaN    NaN
# 936            13.0    5.0           8.0        0.0               NaN    4.0
#
#     Adults  Youth Children Current_season_start Current_season_finish  \
# 0    49.50  39.50       25           2021-12-04          2022-04-18__
# 1       52     37      NaN           2021-11-26          2022-04-18__
# 2       78     51       25           2021-10-30          2022-04-18__
# 3       55  34.50      NaN           2021-11-25          2022-05-01__
# 4       51     41    25.50           2021-12-03          2022-04-18__
# ..     ...    ...      ...                  ...                   ...
# 932    NaN    NaN      NaN                  NaN                   NaN
# 933    NaN    NaN      NaN                  NaN                   NaN
# 934    NaN    NaN      NaN                  NaN                   NaN
# 935    NaN    NaN      NaN                  NaN                   NaN
# 936     17     13      NaN           2021-12-25          2022-03-13__
#
#     General_season_start General_season_finish Opening_time Closing_time
# 0         early December           mid April__        08:30      16:30__
# 1          late November          late April__        08:30      16:30__
# 2         early November           mid April__        08:30      16:30__
# 3          late November           early May__        08:30      16:00__
# 4           mid December           mid April__        08:30      16:00__
# ..                   ...                   ...          ...          ...
# 932                  NaN                   NaN        09:00      16:00__
# 933                  NaN                   NaN        09:00      16:00__
# 934                  NaN                   NaN          NaN          NaN
# 935                  NaN                   NaN        08:30      17:00__
# 936         mid December           mid March__        09:00      17:00__
#
# [937 rows x 18 columns]

# %% [markdown]
# # Current season finish

# %%
lista1 = []
for i in dfINAL['Current_season_finish']:
    try:
        a=i.replace("__", "")
        lista1.append(a)
    except:
        lista1.append('nan')

# %%
a = pd.DataFrame(lista1)

# %%
dfINAL['Current_season_finish'] = a[0]

# %%
dfINAL
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 0                    Lermoos – Grubigstein          1004          2100
# 1    Latemar – Obereggen/Pampeago/Predazzo          1540          2388
# 2                        Arosa Lenzerheide          1229          2865
# 3         Ischgl/Samnaun – Silvretta Arena          1360          2872
# 4         Ski Juwel Alpbachtal Wildschönau           830          2025
# ..                                     ...           ...           ...
# 932                                 Pallas           440           780
# 933                              Eikedalen           457           918
# 934                      Valbella – Gallio          1100          1311
# 935                Caldirola – Monte Gropà          1075          1429
# 936   Kreuzberg – Bischofsheim an der Rhön           610           928
#
#      Pistas_Totales   Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3   12.8          12.6        1.9               1.7    8.0
# 1              49.0    9.3          32.8        6.9               NaN   18.0
# 2             225.0  110.0          87.0       28.0               NaN   43.0
# 3             239.0   47.0         143.0       49.0              15.0   41.0
# 4              90.9   25.1          53.1       12.7              16.3   46.0
# ..              ...    ...           ...        ...               ...    ...
# 932            12.0    8.0           3.0        1.0               NaN    2.0
# 933            15.0   10.0           5.0        0.0               NaN    8.0
# 934            11.2    8.0           2.5        0.7               NaN    NaN
# 935             5.9    4.0           1.9        0.0               NaN    NaN
# 936            13.0    5.0           8.0        0.0               NaN    4.0
#
#     Adults  Youth Children Current_season_start Current_season_finish  \
# 0    49.50  39.50       25           2021-12-04            2022-04-18
# 1       52     37      NaN           2021-11-26            2022-04-18
# 2       78     51       25           2021-10-30            2022-04-18
# 3       55  34.50      NaN           2021-11-25            2022-05-01
# 4       51     41    25.50           2021-12-03            2022-04-18
# ..     ...    ...      ...                  ...                   ...
# 932    NaN    NaN      NaN                  NaN                   nan
# 933    NaN    NaN      NaN                  NaN                   nan
# 934    NaN    NaN      NaN                  NaN                   nan
# 935    NaN    NaN      NaN                  NaN                   nan
# 936     17     13      NaN           2021-12-25            2022-03-13
#
#     General_season_start General_season_finish Opening_time Closing_time
# 0         early December           mid April__        08:30      16:30__
# 1          late November          late April__        08:30      16:30__
# 2         early November           mid April__        08:30      16:30__
# 3          late November           early May__        08:30      16:00__
# 4           mid December           mid April__        08:30      16:00__
# ..                   ...                   ...          ...          ...
# 932                  NaN                   NaN        09:00      16:00__
# 933                  NaN                   NaN        09:00      16:00__
# 934                  NaN                   NaN          NaN          NaN
# 935                  NaN                   NaN        08:30      17:00__
# 936         mid December           mid March__        09:00      17:00__
#
# [937 rows x 18 columns]

# %% [markdown]
# # General_season_finish

# %%
dfINAL['General_season_finish'].unique()
# Out:
# array(['mid April__', 'late April__', 'early May__', 'early April__',
#        'late March__', 'early July__',
#        'early May__mid June - early August__', nan,
#        'late April__depending on snow conditions - depending on snow conditions__',
#        'late April__mid June - late August__late October - early November__',
#        'late May__', 'early June__', 'mid May__',
#        'depending on snow conditions__',
#        'late March__early July - late August__',
#        'mid November__mid December - early May__', 'early March__',
#        'mid March__', 'early December__late December - early May__',
#        'early November__', 'mid June__'], dtype=object)

# %%
lista2 = []
for i in dfINAL['General_season_finish']:
    try:
        a = i.replace("__", "")
        lista2.append(a)
    except:
        lista1.append('nan')

# %%
b = pd.DataFrame(lista2)

# %%
b
# Out:
#                0
# 0      mid April
# 1     late April
# 2      mid April
# 3      early May
# 4      mid April
# ..           ...
# 667  early March
# 668   late March
# 669   late March
# 670    mid March
# 671    mid March
#
# [672 rows x 1 columns]

# %%
dfINAL['General_season_finish'] = b[0]

# %%
dfINAL
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 0                    Lermoos – Grubigstein          1004          2100
# 1    Latemar – Obereggen/Pampeago/Predazzo          1540          2388
# 2                        Arosa Lenzerheide          1229          2865
# 3         Ischgl/Samnaun – Silvretta Arena          1360          2872
# 4         Ski Juwel Alpbachtal Wildschönau           830          2025
# ..                                     ...           ...           ...
# 932                                 Pallas           440           780
# 933                              Eikedalen           457           918
# 934                      Valbella – Gallio          1100          1311
# 935                Caldirola – Monte Gropà          1075          1429
# 936   Kreuzberg – Bischofsheim an der Rhön           610           928
#
#      Pistas_Totales   Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3   12.8          12.6        1.9               1.7    8.0
# 1              49.0    9.3          32.8        6.9               NaN   18.0
# 2             225.0  110.0          87.0       28.0               NaN   43.0
# 3             239.0   47.0         143.0       49.0              15.0   41.0
# 4              90.9   25.1          53.1       12.7              16.3   46.0
# ..              ...    ...           ...        ...               ...    ...
# 932            12.0    8.0           3.0        1.0               NaN    2.0
# 933            15.0   10.0           5.0        0.0               NaN    8.0
# 934            11.2    8.0           2.5        0.7               NaN    NaN
# 935             5.9    4.0           1.9        0.0               NaN    NaN
# 936            13.0    5.0           8.0        0.0               NaN    4.0
#
#     Adults  Youth Children Current_season_start Current_season_finish  \
# 0    49.50  39.50       25           2021-12-04            2022-04-18
# 1       52     37      NaN           2021-11-26            2022-04-18
# 2       78     51       25           2021-10-30            2022-04-18
# 3       55  34.50      NaN           2021-11-25            2022-05-01
# 4       51     41    25.50           2021-12-03            2022-04-18
# ..     ...    ...      ...                  ...                   ...
# 932    NaN    NaN      NaN                  NaN                   nan
# 933    NaN    NaN      NaN                  NaN                   nan
# 934    NaN    NaN      NaN                  NaN                   nan
# 935    NaN    NaN      NaN                  NaN                   nan
# 936     17     13      NaN           2021-12-25            2022-03-13
#
#     General_season_start General_season_finish Opening_time Closing_time
# 0         early December             mid April        08:30      16:30__
# 1          late November            late April        08:30      16:30__
# 2         early November             mid April        08:30      16:30__
# 3          late November             early May        08:30      16:00__
# 4           mid December             mid April        08:30      16:00__
# ..                   ...                   ...          ...          ...
# 932                  NaN                   NaN        09:00      16:00__
# 933                  NaN                   NaN        09:00      16:00__
# 934                  NaN                   NaN          NaN          NaN
# 935                  NaN                   NaN        08:30      17:00__
# 936         mid December                   NaN        09:00      17:00__
#
# [937 rows x 18 columns]

# %% [markdown]
# # Closing_time

# %%
lista3 = []
for i in dfINAL['Closing_time']:
    try:
        a=i.replace("__", "")
        lista3.append(a)
    except:
        lista3.append('nan')

# %%
c = pd.DataFrame(lista3)

# %%
dfINAL['Closing_time'] = c[0]

# %%
dfINAL
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 0                    Lermoos – Grubigstein          1004          2100
# 1    Latemar – Obereggen/Pampeago/Predazzo          1540          2388
# 2                        Arosa Lenzerheide          1229          2865
# 3         Ischgl/Samnaun – Silvretta Arena          1360          2872
# 4         Ski Juwel Alpbachtal Wildschönau           830          2025
# ..                                     ...           ...           ...
# 932                                 Pallas           440           780
# 933                              Eikedalen           457           918
# 934                      Valbella – Gallio          1100          1311
# 935                Caldirola – Monte Gropà          1075          1429
# 936   Kreuzberg – Bischofsheim an der Rhön           610           928
#
#      Pistas_Totales   Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3   12.8          12.6        1.9               1.7    8.0
# 1              49.0    9.3          32.8        6.9               NaN   18.0
# 2             225.0  110.0          87.0       28.0               NaN   43.0
# 3             239.0   47.0         143.0       49.0              15.0   41.0
# 4              90.9   25.1          53.1       12.7              16.3   46.0
# ..              ...    ...           ...        ...               ...    ...
# 932            12.0    8.0           3.0        1.0               NaN    2.0
# 933            15.0   10.0           5.0        0.0               NaN    8.0
# 934            11.2    8.0           2.5        0.7               NaN    NaN
# 935             5.9    4.0           1.9        0.0               NaN    NaN
# 936            13.0    5.0           8.0        0.0               NaN    4.0
#
#     Adults  Youth Children Current_season_start Current_season_finish  \
# 0    49.50  39.50       25           2021-12-04            2022-04-18
# 1       52     37      NaN           2021-11-26            2022-04-18
# 2       78     51       25           2021-10-30            2022-04-18
# 3       55  34.50      NaN           2021-11-25            2022-05-01
# 4       51     41    25.50           2021-12-03            2022-04-18
# ..     ...    ...      ...                  ...                   ...
# 932    NaN    NaN      NaN                  NaN                   nan
# 933    NaN    NaN      NaN                  NaN                   nan
# 934    NaN    NaN      NaN                  NaN                   nan
# 935    NaN    NaN      NaN                  NaN                   nan
# 936     17     13      NaN           2021-12-25            2022-03-13
#
#     General_season_start General_season_finish Opening_time Closing_time
# 0         early December             mid April        08:30        16:30
# 1          late November            late April        08:30        16:30
# 2         early November             mid April        08:30        16:30
# 3          late November             early May        08:30        16:00
# 4           mid December             mid April        08:30        16:00
# ..                   ...                   ...          ...          ...
# 932                  NaN                   NaN        09:00        16:00
# 933                  NaN                   NaN        09:00        16:00
# 934                  NaN                   NaN          NaN          nan
# 935                  NaN                   NaN        08:30        17:00
# 936         mid December                   NaN        09:00        17:00
#
# [937 rows x 18 columns]

# %%
dfINAL.sample(10)
# Out:
#                                     Nombre Minima Altura Maxima Altura  \
# 321                   Vals 3000 – Dachberg          1286          2941
# 706                                 Parâng          1300          1720
# 852                 Haukelifjell Skisenter           855          1216
# 308                 Gourette (Eaux Bonnes)          1350          2450
# 387                   Wasserngrat – Gstaad          1275          1900
# 1    Latemar – Obereggen/Pampeago/Predazzo          1540          2388
# 569                   Sattel – Hochstuckli           800          1491
# 158                     Bad Kleinkirchheim          1087          2055
# 133                            Kreischberg           868          2118
# 482                      Gaissau-Hintersee           750          1567
#
#      Pistas_Totales  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 321            25.0   5.0          15.0        5.0               NaN    5.0
# 706             8.0   0.6           4.3        3.1               NaN    NaN
# 852            14.2   2.4           9.2        2.6               NaN    6.0
# 308            35.0  18.0          13.0        4.0               NaN    9.0
# 387             9.3   3.5           3.6        2.2               NaN    1.0
# 1              49.0   9.3          32.8        6.9               NaN   18.0
# 569            12.0   6.0           6.0        0.0               2.0    5.0
# 158           103.0  18.0          77.0        8.0               5.0   22.0
# 133            42.5  17.5          16.0        9.0               NaN   13.0
# 482            30.0  20.0           9.0        1.0               NaN    8.0
#
#     Adults  Youth Children Current_season_start Current_season_finish  \
# 321     30    NaN      NaN           2021-12-18            2022-04-18
# 706    NaN    NaN      NaN                  NaN                   nan
# 852    NaN    NaN      NaN                  NaN                   nan
# 308     38  32.50      NaN           2021-12-11            2022-04-03
# 387    NaN    NaN      NaN                  NaN                   nan
# 1       52     37      NaN           2021-11-26            2022-04-18
# 569     36     30       18           2021-12-04            2022-03-20
# 158  52.50     40    26.50           2021-12-03            2022-04-03
# 133     52  41.50       26           2021-12-04            2022-04-03
# 482     41     32       18           2021-12-11            2022-04-03
#
#     General_season_start General_season_finish Opening_time Closing_time
# 321         mid December            late March        09:00        16:30
# 706                  NaN                   NaN          NaN          nan
# 852                  NaN                   NaN        10:00        16:00
# 308       early December           early April        08:45        17:00
# 387         mid December            late March        09:30        16:30
# 1          late November            late April        08:30        16:30
# 569         mid December             mid March        09:00        16:15
# 158       early December           early April        09:00        16:00
# 133       early December            late April        08:30        16:00
# 482         mid December              mid June        09:00        16:00

# %%
dfINAL.rename(columns=lambda x: x.replace('Nombre', 'Name'), inplace=True)

# %%
dfINAL.rename(columns=lambda x: x.replace('Minima Altura', 'Min_Altitude'), inplace=True)

# %%
dfINAL.rename(columns=lambda x: x.replace('Maxima Altura', 'Max_Altitude'), inplace=True)

# %%
dfINAL.rename(columns=lambda x: x.replace('Pistas_Totales', 'Total_ski_routes'), inplace=True)

# %%
dfINAL
# Out:
#                                       Name Min_Altitude Max_Altitude  \
# 0                    Lermoos – Grubigstein         1004         2100
# 1    Latemar – Obereggen/Pampeago/Predazzo         1540         2388
# 2                        Arosa Lenzerheide         1229         2865
# 3         Ischgl/Samnaun – Silvretta Arena         1360         2872
# 4         Ski Juwel Alpbachtal Wildschönau          830         2025
# ..                                     ...          ...          ...
# 932                                 Pallas          440          780
# 933                              Eikedalen          457          918
# 934                      Valbella – Gallio         1100         1311
# 935                Caldirola – Monte Gropà         1075         1429
# 936   Kreuzberg – Bischofsheim an der Rhön          610          928
#
#      Total_ski_routes   Easy  Intermediate  Difficult  Aditional_Routes  \
# 0                27.3   12.8          12.6        1.9               1.7
# 1                49.0    9.3          32.8        6.9               NaN
# 2               225.0  110.0          87.0       28.0               NaN
# 3               239.0   47.0         143.0       49.0              15.0
# 4                90.9   25.1          53.1       12.7              16.3
# ..                ...    ...           ...        ...               ...
# 932              12.0    8.0           3.0        1.0               NaN
# 933              15.0   10.0           5.0        0.0               NaN
# 934              11.2    8.0           2.5        0.7               NaN
# 935               5.9    4.0           1.9        0.0               NaN
# 936              13.0    5.0           8.0        0.0               NaN
#
#      Lifts Adults  Youth Children Current_season_start Current_season_finish  \
# 0      8.0  49.50  39.50       25           2021-12-04            2022-04-18
# 1     18.0     52     37      NaN           2021-11-26            2022-04-18
# 2     43.0     78     51       25           2021-10-30            2022-04-18
# 3     41.0     55  34.50      NaN           2021-11-25            2022-05-01
# 4     46.0     51     41    25.50           2021-12-03            2022-04-18
# ..     ...    ...    ...      ...                  ...                   ...
# 932    2.0    NaN    NaN      NaN                  NaN                   nan
# 933    8.0    NaN    NaN      NaN                  NaN                   nan
# 934    NaN    NaN    NaN      NaN                  NaN                   nan
# 935    NaN    NaN    NaN      NaN                  NaN                   nan
# 936    4.0     17     13      NaN           2021-12-25            2022-03-13
#
#     General_season_start General_season_finish Opening_time Closing_time
# 0         early December             mid April        08:30        16:30
# 1          late November            late April        08:30        16:30
# 2         early November             mid April        08:30        16:30
# 3          late November             early May        08:30        16:00
# 4           mid December             mid April        08:30        16:00
# ..                   ...                   ...          ...          ...
# 932                  NaN                   NaN        09:00        16:00
# 933                  NaN                   NaN        09:00        16:00
# 934                  NaN                   NaN          NaN          nan
# 935                  NaN                   NaN        08:30        17:00
# 936         mid December                   NaN        09:00        17:00
#
# [937 rows x 18 columns]

# %%
a = dfINAL.Min_Altitude

# %%
listOfStrings1 = ['Europe'] * 937

# %%
dfloc = pd.DataFrame(listOfStrings1)

# %%
dfloc
dfloc = dfloc.rename(columns={0:"Contintent"})

# %%
dfloc
# Out:
#     Contintent
# 0       Europe
# 1       Europe
# 2       Europe
# 3       Europe
# 4       Europe
# ..         ...
# 932     Europe
# 933     Europe
# 934     Europe
# 935     Europe
# 936     Europe
#
# [937 rows x 1 columns]

# %%
dfINAL.insert(1, 'Continent', listOfStrings1)

# %%
dfINAL
# Out:
#                                       Name Continent Min_Altitude  \
# 0                    Lermoos – Grubigstein    Europe         1004
# 1    Latemar – Obereggen/Pampeago/Predazzo    Europe         1540
# 2                        Arosa Lenzerheide    Europe         1229
# 3         Ischgl/Samnaun – Silvretta Arena    Europe         1360
# 4         Ski Juwel Alpbachtal Wildschönau    Europe          830
# ..                                     ...       ...          ...
# 932                                 Pallas    Europe          440
# 933                              Eikedalen    Europe          457
# 934                      Valbella – Gallio    Europe         1100
# 935                Caldirola – Monte Gropà    Europe         1075
# 936   Kreuzberg – Bischofsheim an der Rhön    Europe          610
#
#     Max_Altitude  Total_ski_routes   Easy  Intermediate  Difficult  \
# 0           2100              27.3   12.8          12.6        1.9
# 1           2388              49.0    9.3          32.8        6.9
# 2           2865             225.0  110.0          87.0       28.0
# 3           2872             239.0   47.0         143.0       49.0
# 4           2025              90.9   25.1          53.1       12.7
# ..           ...               ...    ...           ...        ...
# 932          780              12.0    8.0           3.0        1.0
# 933          918              15.0   10.0           5.0        0.0
# 934         1311              11.2    8.0           2.5        0.7
# 935         1429               5.9    4.0           1.9        0.0
# 936          928              13.0    5.0           8.0        0.0
#
#      Aditional_Routes  Lifts Adults  Youth Children Current_season_start  \
# 0                 1.7    8.0  49.50  39.50       25           2021-12-04
# 1                 NaN   18.0     52     37      NaN           2021-11-26
# 2                 NaN   43.0     78     51       25           2021-10-30
# 3                15.0   41.0     55  34.50      NaN           2021-11-25
# 4                16.3   46.0     51     41    25.50           2021-12-03
# ..                ...    ...    ...    ...      ...                  ...
# 932               NaN    2.0    NaN    NaN      NaN                  NaN
# 933               NaN    8.0    NaN    NaN      NaN                  NaN
# 934               NaN    NaN    NaN    NaN      NaN                  NaN
# 935               NaN    NaN    NaN    NaN      NaN                  NaN
# 936               NaN    4.0     17     13      NaN           2021-12-25
#
#     Current_season_finish General_season_start General_season_finish  \
# 0              2022-04-18       early December             mid April
# 1              2022-04-18        late November            late April
# 2              2022-04-18       early November             mid April
# 3              2022-05-01        late November             early May
# 4              2022-04-18         mid December             mid April
# ..                    ...                  ...                   ...
# 932                   nan                  NaN                   NaN
# 933                   nan                  NaN                   NaN
# 934                   nan                  NaN                   NaN
# 935                   nan                  NaN                   NaN
# 936            2022-03-13         mid December                   NaN
#
#     Opening_time Closing_time
# 0          08:30        16:30
# 1          08:30        16:30
# 2          08:30        16:30
# 3          08:30        16:00
# 4          08:30        16:00
# ..           ...          ...
# 932        09:00        16:00
# 933        09:00        16:00
# 934          NaN          nan
# 935        08:30        17:00
# 936        09:00        17:00
#
# [937 rows x 19 columns]

# %%
dfINAL.to_csv("Data/EuropaFin.csv")
