# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
from selenium.webdriver.chrome.options import Options
import sys
import regex as re
import pandas as pd

# %%
nombres = pd.read_csv('Data/nombresesp.csv')
Metros = pd.read_csv('Data/metrosesp.csv')
pistas = pd.read_csv('Data/pistasesp.csv')
remontes = pd.read_csv('Data/remontesesp.csv')
precios = pd.read_csv('Data/preciosesp.csv')
temporada = pd.read_csv('Data/Seasonesp.csv')

# %%
dfINAL = pd.concat([nombres,Metros,pistas,remontes,precios,temporada], axis=1)

# %%
dfINAL = dfINAL.drop('Unnamed: 0', 1)
# Out:
# <ipython-input-33-448f5175fe73>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dfINAL = dfINAL.drop('Unnamed: 0', 1)

# %%
dfINAL
# Out:
#                             Nombre Minima Altura Maxima Altura  \
# 0                   Baqueira/Beret      __1500 m        2610 m
# 1                         Formigal      __1501 m        2251 m
# 2      La Molina/Masella – Alp2500      __1616 m        2531 m
# 3       Sierra Nevada – Pradollano      __2100 m        3282 m
# 4                           Cerler      __1505 m        2630 m
# 5                        Panticosa      __1146 m        2204 m
# 6                        Boí Taüll      __2020 m        2751 m
# 7                      Espot Esqui      __1510 m        2291 m
# 8                        Candanchú      __1514 m        2236 m
# 9                            Astún      __1655 m        2272 m
# 10                  Port del Comte      __1745 m        2310 m
# 11                     Valdezcaray      __1548 m        2135 m
# 12                       Port Ainé      __1650 m        2421 m
# 13                      La Pinilla      __1484 m        2036 m
# 14                     Alto Campoo      __1650 m        2120 m
# 15               Valgrande Pajares      __1455 m        1840 m
# 16       San Isidro-Zona Cebolledo      __1640 m        2030 m
# 17  La Covatilla – Sierra de Béjar      __1990 m        2368 m
# 18                       Valdesquí      __1860 m        2278 m
# 19              Puerto Navacerrada      __1703 m        2174 m
# 20                      Javalambre      __1650 m        2000 m
# 21             Fuentes de Invierno      __1487 m        1950 m
# 22                       Manzaneda      __1505 m        1760 m
# 23  Valdelinares (Sierra de Gúdar)      __1737 m        1979 m
# 24                    Vallter 2000      __1959 m        2535 m
# 25                     Leitariegos      __1513 m        1800 m
# 26       Pleta del Prat – Tavascan      __1712 m        2197 m
# 27                   Vall de Núria     __ 1964 m        2260 m
# 28       San Isidro-Zona Salencias      __1502 m        1670 m
# 29                Rasos de Peguera      __1825 m        2035 m
# 30                Madrid Snow Zone       __667 m         705 m
# 31       Punto de Nieve Santa Inés      __1753 m        1832 m
#
#     Pistas_Totales  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0            160.0  80.0          60.0       20.0               5.0   29.0
# 1            137.0  47.0          70.0       20.0               NaN   15.0
# 2            141.0  76.0          47.0       18.0               NaN   28.0
# 3            107.0  50.0          49.0        7.8               NaN   17.0
# 4             81.0  37.0          29.0       15.0               NaN   13.0
# 5             35.0  11.0          21.0        3.0               NaN   10.0
# 6             41.3  10.0          22.7        8.6               2.7    7.0
# 7             25.0  13.0           8.0        4.0               NaN    3.0
# 8             50.0  15.8          18.3       15.9              11.2   21.0
# 9             39.9  16.8          18.8        4.3              10.1   12.0
# 10            40.0  20.0          15.0        5.0               NaN   14.0
# 11            22.0  10.0          10.0        2.0               2.0   10.0
# 12            26.7  10.7          11.7        4.3               NaN    6.0
# 13            21.0  14.0           6.0        1.0               NaN   11.0
# 14            27.7  13.6          10.9        3.2               NaN   13.0
# 15            25.0  12.0          10.0        3.0               NaN    8.0
# 16            20.8   6.8           9.5        4.5               3.5    7.0
# 17            26.8   8.6          18.2        0.0               NaN    3.0
# 18            22.3  18.8           3.5        0.0               NaN   13.0
# 19            10.0   3.0           6.0        1.0               NaN    5.0
# 20            15.0  14.0           1.0        0.0               NaN    7.0
# 21             8.8   4.2           3.3        1.3               NaN    4.0
# 22            10.0   8.0           2.0        0.0               NaN    6.0
# 23            17.0  10.0           7.0        0.0               NaN    9.0
# 24            10.4   5.4           4.0        1.0               6.3    8.0
# 25             7.0   4.0           3.0        0.0               NaN    6.0
# 26             5.0   1.0           4.0        0.0               NaN    2.0
# 27             7.6   4.1           2.5        1.0               NaN    5.0
# 28             6.5   2.9           3.6        0.0               NaN    4.0
# 29             5.0   3.0           2.0        0.0               NaN    NaN
# 30             0.3   0.2           0.1        0.0               NaN    3.0
# 31             1.8   1.0           0.8        0.0               NaN    NaN
#
#      Adults  Youth Children Current_season_start Current_season_finish  \
# 0    54.50     NaN     36']           2021-11-27          2022-04-18__
# 1    49.50     NaN     40']           2021-11-27          2022-04-18__
# 2      48']    NaN      NaN           2021-11-27          2022-04-18__
# 3      52']    NaN      NaN           2021-12-04          2022-04-18__
# 4       NaN    NaN      NaN           2021-12-04          2022-04-18__
# 5    43.50     NaN     35']                  NaN                   NaN
# 6      39']    NaN      NaN                  NaN                   NaN
# 7      34']    NaN      NaN                  NaN                   NaN
# 8      45']    NaN      NaN           2021-12-04          2022-04-18__
# 9      45']    NaN      NaN                  NaN                   NaN
# 10     36']    NaN      NaN                  NaN                   NaN
# 11     29']    NaN      NaN                  NaN                   NaN
# 12     34']    NaN      NaN                  NaN                   NaN
# 13     35']    NaN      NaN                  NaN                   NaN
# 14     34']    NaN      NaN                  NaN                   NaN
# 15     28']    NaN      NaN                  NaN                   NaN
# 16     30']    NaN      NaN                  NaN                   NaN
# 17     29']    NaN      NaN                  NaN                   NaN
# 18     38']    NaN      NaN                  NaN                   NaN
# 19     27']    NaN      NaN                  NaN                   NaN
# 20     36']    NaN      NaN                  NaN                   NaN
# 21     27']    NaN      NaN           2021-12-04          2022-04-03__
# 22     25']    NaN      NaN                  NaN                   NaN
# 23   37.50     NaN     30']                  NaN                   NaN
# 24     27']    NaN      NaN                  NaN                   NaN
# 25     22']    NaN      NaN                  NaN                   NaN
# 26     22']    NaN      NaN                  NaN                   NaN
# 27     31']    NaN      NaN                  NaN                   NaN
# 28     30']    NaN      NaN                  NaN                   NaN
# 29      NaN    NaN      NaN                  NaN                   NaN
# 30     39']    NaN      NaN                  NaN                   NaN
# 31      NaN    NaN      NaN                  NaN                   NaN
#
#    General_season_start General_season_finish Opening_time Closing_time
# 0        early December           mid April__        08:45      16:45__
# 1         late November           mid April__        09:00      17:00__
# 2         late November          late April__        09:00      16:00__
# 3         late November           early May__        09:00      16:45__
# 4        early December         early April__        09:00      16:30__
# 5        early December         early April__        09:00      17:00__
# 6                   NaN                   NaN          NaN          NaN
# 7        early December         early April__        09:00      16:00__
# 8        early December         early April__        09:00      17:00__
# 9                   NaN                   NaN          NaN          NaN
# 10                  NaN                   NaN          NaN          NaN
# 11                  NaN                   NaN        09:00      17:00__
# 12                  NaN                   NaN          NaN          NaN
# 13       early December         early April__        09:00      16:30__
# 14                  NaN                   NaN          NaN          NaN
# 15                  NaN                   NaN          NaN          NaN
# 16                  NaN                   NaN          NaN          NaN
# 17                  NaN                   NaN          NaN          NaN
# 18                  NaN                   NaN        09:00      16:30__
# 19                  NaN                   NaN          NaN          NaN
# 20                  NaN                   NaN        09:00      17:00__
# 21       early December         early April__        09:00      16:45__
# 22                  NaN                   NaN          NaN          NaN
# 23       early December         early April__        08:30      17:00__
# 24       early December         early April__        09:00      16:45__
# 25                  NaN                   NaN          NaN          NaN
# 26                  NaN                   NaN        09:00      16:00__
# 27                  NaN                   NaN          NaN          NaN
# 28                  NaN                   NaN          NaN          NaN
# 29                  NaN                   NaN          NaN          NaN
# 30         Year-round__                   NaN        09:00      22:00__
# 31                  NaN                   NaN          NaN          NaN

# %%
def limpia_col(dfcol):
    for i in dfcol:
        a = dfcol.str.extract('((\d+)+(\.\d+)|(\d+))', flags=0)
        a = a.rename(columns={0:"Primera"})
    return a.Primera

# %%
dfINAL['Minima Altura'] = limpia_col(dfINAL['Minima Altura'])
dfINAL['Maxima Altura'] = limpia_col(dfINAL['Maxima Altura'])
dfINAL['Adults'] = limpia_col(dfINAL['Adults'])
dfINAL['Children'] = limpia_col(dfINAL['Children'])

# %%
lista1 = []
def quitar__(dfcol):
    for i in dfcol:
        try:
            a=i.replace("__", "")
            lista1.append(a)
        except:
            lista1.append('nan')
    a =  pd.DataFrame(lista1)
    dfcol = a[0]

# %%
quitar__(dfINAL.Current_season_finish)

# %%
lista1 = []
for i in dfINAL['Current_season_finish']:
    try:
        a=i.replace("__", "")
        lista1.append(a)
    except:
        lista1.append('nan')

# %%
a = pd.DataFrame(lista1)

# %%
dfINAL['Current_season_finish'] = a[0]

# %%
lista2 = []
for i in dfINAL['General_season_finish']:
    try:
        a = i.replace("__", "")
        lista2.append(a)
    except:
        lista1.append('nan')

# %%
b = pd.DataFrame(lista2)

# %%
dfINAL['General_season_finish'] = b[0]

# %%
lista3 = []
for i in dfINAL['Closing_time']:
    try:
        a=i.replace("__", "")
        lista3.append(a)
    except:
        lista3.append('nan')

# %%
c = pd.DataFrame(lista3)

# %%
dfINAL['Closing_time'] = c[0]

# %%
dfINAL.rename(columns=lambda x: x.replace('Nombre', 'Name'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Minima Altura', 'Min_Altitude'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Maxima Altura', 'Max_Altitude'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Pistas_Totales', 'Total_ski_routes'), inplace=True)

# %%
dfINAL.to_csv("Data/dfespañafinal")
