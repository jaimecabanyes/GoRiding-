# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
dfcomp = pd.read_csv('Data2/entero.csv')

# %%
dfcomp = dfcomp.drop(columns='Unnamed: 0')

# %%
dfcomp.head(1)
# Out:
#                     Name Continent   Country  Min_Altitude  Max_Altitude  \
# 0  Lermoos   Grubigstein    Europe   Austria          1004          2100
#
#    Total_ski_routes  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0              27.3  12.8          12.6        1.9               1.7    8.0
#
#    Adults Current_season_start Current_season_finish General_season_start  \
# 0    49.5           2021-12-04            2022-04-18       early December
#
#   General_season_finish Opening_time Closing_time
# 0             mid April        08:30        16:30

# %%
dfcomp = dfcomp.dropna(subset=['Country'])

# %%
dfcomp = dfcomp.dropna(subset=['Total_ski_routes'])

# %%
dfcomp = dfcomp.dropna(subset=['Adults'])

# %%
dfcomp.drop(dfcomp.loc[dfcomp['Country']=='error'].index, inplace=True)

# %%
dfcomp.to_csv("Data2/FINAL!!!!!.csv")

# %% [markdown]
# # VISUALIZACION

# %%
dfcomp["Country"].value_counts().plot(kind="bar",
                                        figsize=(15,6),
                                        title="Estaciones")
plt.xticks(rotation=90);

# %%
sns.boxplot(x="Adults", y = 'Continent', data=dfcomp)
# Out:
# <AxesSubplot:xlabel='Adults', ylabel='Continent'>

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
sns.scatterplot(x="Total_ski_routes", y="Adults", data=dfcomp, hue="Country", palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Total_ski_routes', ylabel='Adults'>

# %% [markdown]
# price =
