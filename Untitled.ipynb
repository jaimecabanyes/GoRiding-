# %% [markdown]
# # Prediccion precio Fortfait

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('Data2/FINAL!!!!!.csv')
df = df.drop([ 'Unnamed: 0',], axis=1)

# %%
df = df
# Out:
#                                  Name Continent         Country  Min_Altitude  \
# 0               Lermoos   Grubigstein    Europe         Austria          1004
# 1                   Arosa Lenzerheide    Europe     Switzerland          1229
# 2    Ski Juwel Alpbachtal Wildschönau    Europe         Austria           830
# 3                Val Gardena (Gröden)    Europe          Italia          1236
# 4                               Arber    Europe     Deutschland          1050
# ..                                ...       ...             ...           ...
# 593                       Mt. Bohemia   America   United States           190
# 594               Jack Frost Mountain   America   United States           427
# 595        Bear Creek Mountain Resort   America   United States           180
# 596                      Tahoe Donner   America   United States          2057
# 597                       Suicide Six   America   United States           220
#
#      Max_Altitude  Total_ski_routes   Easy  Intermediate  Difficult  \
# 0            2100              27.3   12.8          12.6        1.9
# 1            2865             225.0  110.0          87.0       28.0
# 2            2025              90.9   25.1          53.1       12.7
# 3            2518             178.0   52.0         105.0       21.0
# 4            1456              11.5    4.5           4.0        3.0
# ..            ...               ...    ...           ...        ...
# 593           445              13.0    0.0           3.0       10.0
# 594           610              12.0    6.0           5.5        0.5
# 595           335              10.0    3.0           4.0        3.0
# 596          2240              14.0    6.0           8.0        0.0
# 597           411              10.5    3.5           4.0        3.0
#
#      Aditional_Routes  Lifts  Adults Current_season_start  \
# 0                 1.7    8.0    49.5           2021-12-04
# 1                 NaN   43.0    78.0           2021-10-30
# 2                16.3   46.0    51.0           2021-12-03
# 3                 NaN   79.0    64.0           2021-12-04
# 4                 5.0    6.0    36.0           2021-12-11
# ..                ...    ...     ...                  ...
# 593               NaN    2.0    68.0                  NaN
# 594               NaN   11.0   103.0                  NaN
# 595               NaN    4.0    60.0                  NaN
# 596               NaN    2.0    89.0                  NaN
# 597               NaN    3.0    75.0                  NaN
#
#     Current_season_finish General_season_start General_season_finish  \
# 0              2022-04-18       early December             mid April
# 1              2022-04-18       early November             mid April
# 2              2022-04-18         mid December             mid April
# 3              2022-04-10       early December             mid April
# 4              2022-03-27         mid December            late March
# ..                    ...                  ...                   ...
# 593                   NaN         mid December                   NaN
# 594                   NaN                  NaN                   NaN
# 595                   NaN                  NaN                   NaN
# 596                   NaN       early December                   NaN
# 597                   NaN                  NaN                   NaN
#
#     Opening_time                                Closing_time
# 0          08:30                                       16:30
# 1          08:30                                       16:30
# 2          08:30                                       16:00
# 3          08:30                                       16:30
# 4          08:30                                       16:00
# ..           ...                                         ...
# 593        09:30  17:00Limited opening times during the week
# 594        09:00                                       21:00
# 595        09:00                                       21:00
# 596        09:00                                       16:00
# 597        09:00                                       16:00
#
# [598 rows x 18 columns]
