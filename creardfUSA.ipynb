# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep
from selenium.webdriver.chrome.options import Options
import sys
import regex as re
import pandas as pd

# %%
a = pd.read_csv('Data/nombreUSA.csv')
b = pd.read_csv('Data/metrosUSA.csv')
c= pd.read_csv('Data/pistasUSA.csv')
d = pd.read_csv('Data/remontesUSA.csv')
e = pd.read_csv('Data/preciosUSA.csv')
f = pd.read_csv('Data/temporadaUSA.csv')

# %%
dfINAL = pd.concat([a,b,c,d,e,f], axis=1)

# %%
dfINAL = dfINAL.drop('Unnamed: 0', 1)
# Out:
# <ipython-input-4-448f5175fe73>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dfINAL = dfINAL.drop('Unnamed: 0', 1)

# %%
dfINAL
# Out:
#                        Nombre Minima Altura Maxima Altura  Pistas_Totales  \
# 0                    ['Vail']    ['__2457 m    3433 m (']           234.0
# 1               ['Telluride']    ['__2659 m    3815 m (']            88.2
# 2            ['Beaver Creek']    ['__2255 m    3488 m (']           150.0
# 3                ['Snowmass']    ['__2473 m    3813 m (']           237.0
# 4        ['Mammoth Mountain']    ['__2424 m    3369 m (']            89.8
# ..                        ...           ...           ...             ...
# 202          ['Tahoe Donner']    ['__2057 m    2240 m (']            14.0
# 203           ['Suicide Six']     ['__220 m     411 m (']            10.5
# 204             ['Whaleback']     ['__347 m     543 m (']            11.5
# 205  ['Meadowlark Ski Lodge']    ['__2585 m    2828 m (']            10.0
# 206                 ['Swain']     ['__400 m     600 m (']            10.9
#
#      Easy  Intermediate  Difficult  Aditional_Routes  Lifts Adults      Youth  \
# ...

# %%
def limpia_col(dfcol):
    for i in dfcol:
        a = dfcol.str.extract('((\d+)+(\.\d+)|(\d+))', flags=0)
        a = a.rename(columns={0:"Primera"})
    return a.Primera

# %%
dfINAL['Minima Altura'] = limpia_col(dfINAL['Minima Altura'])
dfINAL['Maxima Altura'] = limpia_col(dfINAL['Maxima Altura'])
dfINAL['Adults'] = limpia_col(dfINAL['Adults'])
dfINAL['Children'] = limpia_col(dfINAL['Children'])
dfINAL['Youth'] = limpia_col(dfINAL['Youth'])

# %%
lista1 = []
def quitar__(dfcol):
    for i in dfcol:
        try:
            a=i.replace("__", "")
            lista1.append(a)
        except:
            lista1.append('nan')
    a =  pd.DataFrame(lista1)
    dfcol = a[0]

# %%
quitar__(dfINAL.Current_season_finish)

# %%
lista1 = []
for i in dfINAL['Current_season_finish']:
    try:
        a=i.replace("__", "")
        lista1.append(a)
    except:
        lista1.append('nan')

# %%
a = pd.DataFrame(lista1)

# %%
dfINAL['Current_season_finish'] = a[0]

# %%
lista2 = []
for i in dfINAL['General_season_finish']:
    try:
        a = i.replace("__", "")
        lista2.append(a)
    except:
        lista1.append('nan')

# %%
b = pd.DataFrame(lista2)

# %%
dfINAL['General_season_finish'] = b[0]

# %%
lista3 = []
for i in dfINAL['Closing_time']:
    try:
        a=i.replace("__", "")
        lista3.append(a)
    except:
        lista3.append('nan')

# %%
c = pd.DataFrame(lista3)

# %%
dfINAL['Closing_time'] = c[0]

# %%
dfINAL.rename(columns=lambda x: x.replace('Nombre', 'Name'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Minima Altura', 'Min_Altitude'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Maxima Altura', 'Max_Altitude'), inplace=True)
dfINAL.rename(columns=lambda x: x.replace('Pistas_Totales', 'Total_ski_routes'), inplace=True)

# %%
listOfStrings1 = ['America'] * 207

# %%
dfloc = pd.DataFrame(listOfStrings1)

# %%
dfloc
dfloc = dfloc.rename(columns={0:"Contintent"})

# %%
dfINAL.insert(1, 'Continent', listOfStrings1)

# %%
dfINAL
# Out:
#                          Name Continent Min_Altitude Max_Altitude  \
# 0                    ['Vail']   America         2457         3433
# 1               ['Telluride']   America         2659         3815
# 2            ['Beaver Creek']   America         2255         3488
# 3                ['Snowmass']   America         2473         3813
# 4        ['Mammoth Mountain']   America         2424         3369
# ..                        ...       ...          ...          ...
# 202          ['Tahoe Donner']   America         2057         2240
# 203           ['Suicide Six']   America          220          411
# 204             ['Whaleback']   America          347          543
# 205  ['Meadowlark Ski Lodge']   America         2585         2828
# 206                 ['Swain']   America          400          600
#
#      Total_ski_routes  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0               234.0  57.0          84.0       93.0               NaN   25.0
# ...

# %%
lista1 = []
for i in dfINAL.Name:
    a = i.replace("']", "")
    lista1.append(a)

# %%
dfINAL['Name']= lista1

# %%
dfINAL
# Out:
#                        Name Continent Min_Altitude Max_Altitude  \
# 0                    ['Vail   America         2457         3433
# 1               ['Telluride   America         2659         3815
# 2            ['Beaver Creek   America         2255         3488
# 3                ['Snowmass   America         2473         3813
# 4        ['Mammoth Mountain   America         2424         3369
# ..                      ...       ...          ...          ...
# 202          ['Tahoe Donner   America         2057         2240
# 203           ['Suicide Six   America          220          411
# 204             ['Whaleback   America          347          543
# 205  ['Meadowlark Ski Lodge   America         2585         2828
# 206                 ['Swain   America          400          600
#
#      Total_ski_routes  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 0               234.0  57.0          84.0       93.0               NaN   25.0
# ...

# %%
lista2 = []
for i in dfINAL.Name:
    a = i.replace("['", "")
    lista2.append(a)

# %%
dfINAL['Name']= lista2

# %%
dfINAL.sample(10)
# Out:
#                           Name Continent Min_Altitude Max_Altitude  \
# 35   Wenatchee – Mission Ridge   America         1392         2078
# 92               June Mountain   America         2288         3075
# 14                   Steamboat   America         2103         3221
# 61   Alyeska Resort – Girdwood   America           70          840
# 17              Alpine Meadows   America         2083         2632
# 16             Aspen Highlands   America         2451         3559
# 184                  Whitetail   America          261          545
# 78               Grand Targhee   America         2310         3048
# 65                 Bogus Basin   America         1767         2311
# 125                Mt. Spokane   America         1185         1795
#
#      Total_ski_routes  Easy  Intermediate  Difficult  Aditional_Routes  Lifts  \
# 35              100.0  10.0          60.0       30.0               NaN    4.0
# ...

# %%
dfINAL.to_csv("Data/USAFin.csv")
